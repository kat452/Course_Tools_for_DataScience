# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Author
# Katelyn

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized as per course open-source-tools-for-data-science by IBM.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1) Python
# 2) R
# 3) SQl
# 4) Scala

# %% [markdown]
# **Objectives:**
# - List popular languages for Data Science
# - List popular libraries for Data Scientists
# - List popular tools for Data Scientists

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1) Pandas -python
# 2) NumPy -python
# 3) Matplotlib -python
# 4) Seaborn -python
# 5) Scikit-learn -python
# 6) ggplot2 -R

# %% [markdown]
# |Data Science Tools|
# |---|
# |MySQL|
# |kibana|
# |mleap|

# %%
#This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %%
#This will convert 200 minutes to hours by diving by 60
print(200/60)
#This will give you hours and minutes in a more readable format.
print ( 200//60 ,'hours', 200%60, 'minutes' )
# Out:
# 3.3333333333333335
# 3 hours 20 minutes
